# %%
import pandas
data_frame = pandas.read_csv("data.csv")
data_frame
# Out:
#                   name  ...                  city
# 0        Wynne Cabrera  ...               Tianjin
# 1           Reece Head  ...    Blaenau Ffestiniog
# 2         Pascale Wong  ...               Manukau
# 3         Bevis Bonner  ...            Saint John
# 4       Forrest Weaver  ...                Hainan
# 5       Hollee Charles  ...               Lincoln
# 6        Lesley Prince  ...           Kaliningrad
# 7       Dominic Potter  ...             Melitopol
# 8         Dai Bartlett  ...                  Sumy
# 9        Erasmus Reyes  ...               Calamar
# 10          Judah Byrd  ...                Andong
# 11        Amena Golden  ...                Changi
# 12        Iola Blevins  ...             Thanh Hóa
# 13        Ruth Herrera  ...        Zamboanga City
# 14       Nyssa Hartman  ...               Longaví
# 15       Judah Stanton  ...              Richmond
# 16        Zahir Molina  ...              Mmabatho
# 17     Julie Frederick  ...  San José de Alajuela
# ...

# %%
from pandas import *
data_frame = data_frame.dropna()
data_frame
# Out:
#                   name  ...                  city
# 0        Wynne Cabrera  ...               Tianjin
# 1           Reece Head  ...    Blaenau Ffestiniog
# 2         Pascale Wong  ...               Manukau
# 3         Bevis Bonner  ...            Saint John
# 4       Forrest Weaver  ...                Hainan
# 5       Hollee Charles  ...               Lincoln
# 6        Lesley Prince  ...           Kaliningrad
# 7       Dominic Potter  ...             Melitopol
# 8         Dai Bartlett  ...                  Sumy
# 9        Erasmus Reyes  ...               Calamar
# 10          Judah Byrd  ...                Andong
# 11        Amena Golden  ...                Changi
# 12        Iola Blevins  ...             Thanh Hóa
# 13        Ruth Herrera  ...        Zamboanga City
# 14       Nyssa Hartman  ...               Longaví
# 15       Judah Stanton  ...              Richmond
# 16        Zahir Molina  ...              Mmabatho
# 17     Julie Frederick  ...  San José de Alajuela
# ...
